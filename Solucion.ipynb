# %%
import numpy as np
from src import gauss_jacobi
from src import gauss_seidel
import matplotlib.pyplot as plt

# Sistema de ecuaciones
A = np.array([[2, 10], [3, 2]], dtype=float)
b = np.array([16, 11], dtype=float).reshape(-1, 1)
x0 = np.array([1, 1], dtype=float).reshape(-1, 1)  # Aproximación inicial
tol = 1e-5  # Tolerancia
max_iter = 100  # Número máximo de iteraciones

x_jacobi, tray_jacobi = gauss_jacobi(A=A, b=b, x0=x0, tol=tol, max_iter=max_iter)
print("Método de Jacobi:")
print("Solución aproximada:", x_jacobi.T)

x_seidel, tray_seidel = gauss_seidel(A=A, b=b, x0=x0, tol=tol, max_iter=max_iter)
print("\nMétodo de Gauss-Seidel:")
print("Solución aproximada:", x_seidel.T)

tray_jacobi = np.array(tray_jacobi).squeeze()
tray_seidel = np.array(tray_seidel).squeeze() 

# Solución real para referencia
x_real = [3, 1]

plt.figure(figsize=(10, 6))

plt.plot(
    tray_jacobi[:, 0], tray_jacobi[:, 1], 
    marker="o", label="Gauss-Jacobi", linestyle="--"
)

plt.plot(
    tray_seidel[:, 0], tray_seidel[:, 1], 
    marker="x", label="Gauss-Seidel", linestyle="-."
)

plt.scatter(x_real[0], x_real[1], color="red", label="Solución real", zorder=5)

plt.xlabel("$X_1$")
plt.ylabel("$X_2$")
plt.title("Trayectoria de las iteraciones: Métodos de Jacobi y Gauss-Seidel")
plt.axhline(0, color="gray", linewidth=0.5, linestyle="--")
plt.axvline(0, color="gray", linewidth=0.5, linestyle="--")
plt.legend()
plt.grid()

plt.show()
# Out:
# [01-25 09:22:43][INFO] i= 0 x: [[1. 1.]]
# [01-25 09:22:43][INFO] i= 1 x: [[3. 4.]]
# [01-25 09:22:43][INFO] i= 2 x: [[-12.   1.]]
# [01-25 09:22:43][INFO] i= 3 x: [[ 3.  23.5]]
# [01-25 09:22:43][INFO] i= 4 x: [[-109.5    1. ]]
# [01-25 09:22:43][INFO] i= 5 x: [[  3.   169.75]]
# [01-25 09:22:43][INFO] i= 6 x: [[-840.75    1.  ]]
# [01-25 09:22:43][INFO] i= 7 x: [[   3.    1266.625]]
# [01-25 09:22:43][INFO] i= 8 x: [[-6.325125e+03  1.000000e+00]]
# [01-25 09:22:43][INFO] i= 9 x: [[3.0000000e+00 9.4931875e+03]]
# [01-25 09:22:43][INFO] i= 10 x: [[-4.74579375e+04  1.00000000e+00]]
# [01-25 09:22:43][INFO] i= 11 x: [[3.00000000e+00 7.11924062e+04]]
# [01-25 09:22:43][INFO] i= 12 x: [[-3.55954031e+05  1.00000000e+00]]
# [01-25 09:22:43][INFO] i= 13 x: [[3.00000000e+00 5.33936547e+05]]
# [01-25 09:22:43][INFO] i= 14 x: [[-2.66967473e+06  1.00000000e+00]]
# [01-25 09:22:43][INFO] i= 15 x: [[3.0000000e+00 4.0045176e+06]]
# [01-25 09:22:43][INFO] i= 16 x: [[-2.002258e+07  1.000000e+00]]
# ...

# %%
import numpy as np
from src import gauss_jacobi
from src import gauss_seidel
import matplotlib.pyplot as plt

# Sistema de ecuaciones
A = np.array([[3, 2], [2, 10]], dtype=float)
b = np.array([11, 16], dtype=float).reshape(-1, 1)
x0 = np.array([1, 1], dtype=float).reshape(-1, 1)  # Aproximación inicial
tol = 1e-5  # Tolerancia
max_iter = 100  # Número máximo de iteraciones

x_jacobi, tray_jacobi = gauss_jacobi(A=A, b=b, x0=x0, tol=tol, max_iter=max_iter)
print("Método de Jacobi:")
print("Solución aproximada:", x_jacobi.T)

x_seidel, tray_seidel = gauss_seidel(A=A, b=b, x0=x0, tol=tol, max_iter=max_iter)
print("\nMétodo de Gauss-Seidel:")
print("Solución aproximada:", x_seidel.T)

tray_jacobi = np.array(tray_jacobi).squeeze()
tray_seidel = np.array(tray_seidel).squeeze() 

# Solución real para referencia
x_real = [3, 1]

plt.figure(figsize=(10, 6))

plt.plot(
    tray_jacobi[:, 0], tray_jacobi[:, 1], 
    marker="o", label="Gauss-Jacobi", linestyle="--"
)

plt.plot(
    tray_seidel[:, 0], tray_seidel[:, 1], 
    marker="x", label="Gauss-Seidel", linestyle="-."
)

plt.scatter(x_real[0], x_real[1], color="red", label="Solución real", zorder=5)

plt.xlabel("$X_1$")
plt.ylabel("$X_2$")
plt.title("Trayectoria de las iteraciones: Métodos de Jacobi y Gauss-Seidel")
plt.axhline(0, color="gray", linewidth=0.5, linestyle="--")
plt.axvline(0, color="gray", linewidth=0.5, linestyle="--")
plt.legend()
plt.grid()

plt.show()
# Out:
# [01-25 09:22:43][INFO] i= 0 x: [[1. 1.]]
# [01-25 09:22:43][INFO] i= 1 x: [[3.  1.4]]
# [01-25 09:22:43][INFO] i= 2 x: [[2.73333333 1.        ]]
# [01-25 09:22:43][INFO] i= 3 x: [[3.         1.05333333]]
# [01-25 09:22:43][INFO] i= 4 x: [[2.96444444 1.        ]]
# [01-25 09:22:43][INFO] i= 5 x: [[3.         1.00711111]]
# [01-25 09:22:43][INFO] i= 6 x: [[2.99525926 1.        ]]
# [01-25 09:22:43][INFO] i= 7 x: [[3.         1.00094815]]
# [01-25 09:22:43][INFO] i= 8 x: [[2.9993679 1.       ]]
# [01-25 09:22:43][INFO] i= 9 x: [[3.         1.00012642]]
# [01-25 09:22:43][INFO] i= 10 x: [[2.99991572 1.        ]]
# [01-25 09:22:43][INFO] i= 11 x: [[3.         1.00001686]]
# [01-25 09:22:43][INFO] i= 12 x: [[2.99998876 1.        ]]
# [01-25 09:22:43][INFO] i= 13 x: [[3.         1.00000225]]
# Método de Jacobi:
# Solución aproximada: [[2.9999985 1.       ]]
# [01-25 09:22:43][INFO] i= 0 x: [[1. 1.]]
# [01-25 09:22:43][INFO] i= 1 x: [[3. 1.]]
#
# Método de Gauss-Seidel:
# ...

# %%
import numpy as np
from src import gauss_jacobi
from src import gauss_seidel
import matplotlib.pyplot as plt

# Sistema de ecuaciones
A = np.array([[3, 2], [2, 10]], dtype=float)
b = np.array([11, 16], dtype=float).reshape(-1, 1)
x0 = np.array([5, -2], dtype=float).reshape(-1, 1)  # Aproximación inicial
tol = 1e-5  # Tolerancia
max_iter = 100  # Número máximo de iteraciones

x_jacobi, tray_jacobi = gauss_jacobi(A=A, b=b, x0=x0, tol=tol, max_iter=max_iter)
print("Método de Jacobi:")
print("Solución aproximada:", x_jacobi.T)

x_seidel, tray_seidel = gauss_seidel(A=A, b=b, x0=x0, tol=tol, max_iter=max_iter)
print("\nMétodo de Gauss-Seidel:")
print("Solución aproximada:", x_seidel.T)

tray_jacobi = np.array(tray_jacobi).squeeze()
tray_seidel = np.array(tray_seidel).squeeze() 

# Solución real para referencia
x_real = [3, 1]

plt.figure(figsize=(10, 6))

plt.plot(
    tray_jacobi[:, 0], tray_jacobi[:, 1], 
    marker="o", label="Gauss-Jacobi", linestyle="--"
)

plt.plot(
    tray_seidel[:, 0], tray_seidel[:, 1], 
    marker="x", label="Gauss-Seidel", linestyle="-."
)

plt.scatter(x_real[0], x_real[1], color="red", label="Solución real", zorder=5)

plt.xlabel("$X_1$")
plt.ylabel("$X_2$")
plt.title("Trayectoria de las iteraciones: Métodos de Jacobi y Gauss-Seidel")
plt.axhline(0, color="gray", linewidth=0.5, linestyle="--")
plt.axvline(0, color="gray", linewidth=0.5, linestyle="--")
plt.legend()
plt.grid()

plt.show()
# Out:
# [01-25 09:22:43][INFO] i= 0 x: [[ 5. -2.]]
# [01-25 09:22:43][INFO] i= 1 x: [[5.  0.6]]
# [01-25 09:22:43][INFO] i= 2 x: [[3.26666667 0.6       ]]
# [01-25 09:22:43][INFO] i= 3 x: [[3.26666667 0.94666667]]
# [01-25 09:22:43][INFO] i= 4 x: [[3.03555556 0.94666667]]
# [01-25 09:22:43][INFO] i= 5 x: [[3.03555556 0.99288889]]
# [01-25 09:22:43][INFO] i= 6 x: [[3.00474074 0.99288889]]
# [01-25 09:22:43][INFO] i= 7 x: [[3.00474074 0.99905185]]
# [01-25 09:22:43][INFO] i= 8 x: [[3.0006321  0.99905185]]
# [01-25 09:22:43][INFO] i= 9 x: [[3.0006321  0.99987358]]
# [01-25 09:22:43][INFO] i= 10 x: [[3.00008428 0.99987358]]
# [01-25 09:22:43][INFO] i= 11 x: [[3.00008428 0.99998314]]
# [01-25 09:22:43][INFO] i= 12 x: [[3.00001124 0.99998314]]
# [01-25 09:22:43][INFO] i= 13 x: [[3.00001124 0.99999775]]
# Método de Jacobi:
# Solución aproximada: [[3.0000015  0.99999775]]
# [01-25 09:22:43][INFO] i= 0 x: [[ 5. -2.]]
# [01-25 09:22:43][INFO] i= 1 x: [[5.  0.6]]
# ...
